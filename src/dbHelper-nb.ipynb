# %%
# update how many times each order is made by each user.
# rand user range: [0, 1000] ? 
# rand item range : [34, 70] ?
import random
# import pyrebase
from dbInit import db

# %%
# test submitting order
from order import *
from timeHelpers import getTimeCategory
item1 = Item('item1',{0: 1, 2: 2}, 'large', 1, 'No shake', 1)
item2 = Item('item2',{0: 3}, 'small', 1, 'No Instruction', 2)
order = Order('test_order', getTimeCategory(), [item1, item2])
saveOrder(order)
# Out:
# WEEKDAY_MORNING
# {'test_order': {'category': 'WEEKDAY_MORNING', 'items': {1: {'customizations': {0: 1, 2: 2}, 'instructions': 'No shake', 'quantity': 1, 'sizeCode': 'large'}, 2: {'customizations': {0: 3}, 'instructions': 'No Instruction', 'quantity': 1, 'sizeCode': 'smale'}}}}

# %%
# reinit my fav-db user
# from dbInit import *
# toBeInit= {
#       "Vito Morning Special" : {
#         "category" : "WEEKDAY_MORNING",
#         "items" : {
#           "873068661" : {
#             "customizations" : {
#                 "2": 2,
#                 },
#             "instructions" : "blend with 10mg extra sugar, extra nuts",
#             "name" : "Chestnut Praline Latte",
#             "quantity" : "1",
#             "sizeCode" : "tall"
#           }
#         }
#       },
#       "Vito favorite 1" : {
#         "category" : "WEEKDAY_NIGHT",
#         "items" : {
#           "24" : {
#             "customizations" : {
#               "2" : 1
#             },
#             "instructions" : "extra chocolate syrup, 2 extra expresso shots",
#             "name" : "Peppermint White Chocolate Mocha",
#             "quantity" : 1,
#             "sizeCode" : "small"
#           },
#           "34" : {
#             "customizations" : {
#               "3" : 1
#             },
#             "instructions" : "add extra chocolate syrup, Oreo crunch ",
#             "name" : "Caramel Frappuccino",
#             "quantity" : "1",
#             "sizeCode" : "venti"
#           }
#         }
#       }
#     }
# Out:
# {'3': {'cus_name': 'abv',
#   'customizations': 'abv',
#   'instructions': 'abv',
#   'name': 'abv',
#   'quantity': 1,
#   'sizeCode': 'large'}}

# %%
from dbInit import db
user_id = "NzkGCghmk4MO4mCjwn3DQ8n3LxH2"
# db.child('fav_db').child(user_id).update(toBeInit)

item = {
        3 : {
                'cus_name': "abv", 
                'name': "abv",
                'customizations': "abv",
                'instructions': "abv",
                'quantity': 1,
                'sizeCode': 'large'
            }
    }
db.child('fav_db').child(user_id).child('cart').update({'category': "abv"})
db.child('fav_db').child(user_id).child('cart').child('items').update(item)
# Out:
# {'3': {'cus_name': 'abv',
#   'customizations': 'abv',
#   'instructions': 'abv',
#   'name': 'abv',
#   'quantity': 1,
#   'sizeCode': 'large'}}

# %%
from order import *
user_id = "NzkGCghmk4MO4mCjwn3DQ8n3LxH2"
getCart(user_id)
# Out:
# WEEKDAY_NIGHT

# %%
# generate user-drink-db
user_drink_lst = []
for user in user_list:
    item_count_list = []
    # print("user:", i)
    for k in range (1, 146):
        if random.randint(0,100) < 5:
            rand_quantity = random.randint(1, 10)
            item_count_list.append([int(k), rand_quantity])
            
    user_drink_lst.append([user, item_count_list])     
    # print(item_count_list)   

# print(user_drink_lst)

# %%
userDict = {}
for user in user_drink_lst:
    userId = user[0]
    itemList = user[1]
    
    itemListDic = {}
    for item in itemList:
        
        itemId = item[0]
        quantity = item[1]

        
        
        itemListDic.update({
            itemId: quantity,
                })
        

    userDict.update({
        userId: itemListDic,
    })

print(userDict)
db.child('user-item-db').set(userDict)
# Out:
# {'1XHftVUhoFhBeCoac0p2DhKfoos2': {43: 6, 47: 2, 49: 5, 88: 1, 91: 9, 114: 6, 120: 8, 122: 10, 126: 5, 128: 8, 133: 9, 134: 9, 138: 1}, '262ZKKD4IDWdNTa6BeSHtEljKJi1': {7: 3, 16: 9, 32: 3, 69: 4, 85: 2, 88: 1, 96: 3, 115: 1, 131: 4, 141: 4}, 'JDDERiSBoISfcUULCOKaY3CSPSj1': {27: 8, 50: 6, 109: 1, 112: 3, 114: 8, 126: 7, 131: 9}, 'JrGFrankhHZu2YTsefH7u873SiS2': {17: 2, 54: 1, 116: 9, 132: 5, 134: 4}, 'nGIGiUX0iPP6AMCkMtJP1iPC7rG3': {19: 8, 36: 4, 40: 10, 68: 10, 70: 10, 75: 5, 77: 7, 81: 8}, 'nSiNCo46skYEjbx5HlaeRhflS5H2': {2: 7, 19: 10, 26: 8, 75: 7, 86: 4, 92: 7, 124: 2, 140: 2}, 'test_user1': {15: 2, 51: 9, 97: 5, 107: 4, 142: 2, 143: 9, 145: 2}, 'test_user10': {5: 7, 11: 5, 23: 8, 39: 7, 49: 9, 59: 2, 76: 2, 125: 8}, 'test_user2': {37: 4, 58: 9, 123: 4, 126: 3}, 'test_user3': {8: 8, 20: 1, 112: 3}, 'test_user4': {3: 7, 4: 8, 17: 9, 36: 10, 55: 2, 94: 7, 113: 5, 141: 10}, 'test_user5': {11: 4, 41: 2, 42: 9, 50: 10, 80: 9, 133: 1, 134: 7, 135: 3}, 'test_user6': {6: 6, 18: 4, 36: 5, 68
# ...

# %%
db.set({
  "cust_db" : {
    "drinks" : {
      "hot_coffee" : {
        "test" : {
          "test" : "test"
        }
      }
    }
  },
  "product_db" : {
    "cold_coffee" : {
      "Cold Brews" : {
        "Irish Cream Cold Brew" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 32,
          "name" : "Irish Cream Cold Brew"
        },
        "Salted Caramel Cream Cold Brew" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 33,
          "name" : "Salted Caramel Cream Cold Brew"
        },
        "Starbucks Cold Brew Coffee" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 35,
          "name" : "Starbucks Cold Brew Coffee"
        },
        "Starbucks Cold Brew Coffee with Milk" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 37,
          "name" : "Starbucks Cold Brew Coffee with Milk"
        },
        "Starbucks Reserve Cold Brew" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 34,
          "name" : "Starbucks Reserve Cold Brew"
        },
        "Vanilla Sweet Cream Cold Brew" : {
          "cust_type" : "cold_brew",
          "flavor" : "nutty",
          "id" : 36,
          "name" : "Vanilla Sweet Cream Cold Brew"
        }
      },
      "Iced Americano" : {
        "Iced Caffè Americano" : {
          "cust_type" : "iced_americano",
          "flavor" : "nutty",
          "id" : 41,
          "name" : "Iced Caffè Americano"
        }
      },
      "Iced Coffees" : {
        "Iced Coffee" : {
          "cust_type" : "iced_coffee",
          "flavor" : "nutty",
          "id" : 42,
          "name" : "Iced Coffee"
        },
        "Iced Coffee with Milk" : {
          "cust_type" : "iced_coffee",
          "flavor" : "nutty",
          "id" : 43,
          "name" : "Iced Coffee with Milk"
        },
        "Iced Espresso" : {
          "cust_type" : "iced_coffee",
          "flavor" : "nutty",
          "id" : 45,
          "name" : "Iced Espresso"
        }
      },
      "Iced Flat Whites" : {
        "Iced Flat White" : {
          "cust_type" : "iced_white",
          "flavor" : "nutty",
          "id" : 49,
          "name" : "Iced Flat White"
        },
        "Iced Honey Almondmilk Flat White" : {
          "cust_type" : "iced_white",
          "flavor" : "nutty",
          "id" : 50,
          "name" : "Iced Honey Almondmilk Flat White"
        }
      },
      "Iced Lattes" : {
        "Iced Caffè Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 57,
          "name" : "Iced Caffè Latte"
        },
        "Iced Caramel Brulée Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 54,
          "name" : "Iced Caramel Brulée Latte"
        },
        "Iced Chestnut Praline Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 53,
          "name" : "Iced Chestnut Praline Latte"
        },
        "Iced Cinnamon Dolce Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 58,
          "name" : "Iced Cinnamon Dolce Latte"
        },
        "Iced Pistachio Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 51,
          "name" : "Iced Pistachio Latte"
        },
        "Iced Starbucks Blonde Vanilla Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 59,
          "name" : "Iced Starbucks Blonde Vanilla Latte"
        },
        "Iced Sugar Cookie Almondmilk Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 52,
          "name" : "Iced Sugar Cookie Almondmilk Latte"
        },
        "Starbucks Reserve Iced Hazelnut Bianco Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 56,
          "name" : "Starbucks Reserve Iced Hazelnut Bianco Latte"
        },
        "Starbucks Reserve Iced Latte" : {
          "cust_type" : "iced_latte",
          "flavor" : "nutty",
          "id" : 55,
          "name" : "Starbucks Reserve Iced Latte"
        }
      },
      "Iced Macchiatos" : {
        "Iced Caramel Macchiato" : {
          "cust_type" : "iced_macchiato",
          "flavor" : "nutty",
          "id" : 60,
          "name" : "Iced Caramel Macchiato"
        }
      },
      "Iced Mochas" : {
        "Iced Caffè Mocha" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 65,
          "name" : "Iced Caffè Mocha"
        },
        "Iced Peppermint Mocha" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 64,
          "name" : "Iced Peppermint Mocha"
        },
        "Iced Peppermint White Chocolate Mochao" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 62,
          "name" : "Iced Peppermint White Chocolate Mocha"
        },
        "Iced Toasted White Chocolate Mocha" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 63,
          "name" : "Iced Toasted White Chocolate Mocha"
        },
        "Iced White Chocolate Mocha" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 61,
          "name" : "Iced White Chocolate Mocha"
        },
        "Starbucks Reserve Iced Dark Chocolate Mocha" : {
          "cust_type" : "iced_mocha",
          "flavor" : "nutty",
          "id" : 66,
          "name" : "Starbucks Reserve Iced Dark Chocolate Mocha"
        }
      },
      "Iced Shaken Espresso" : {
        "Iced Brown Sugar Oatmilk Shaken Espresso" : {
          "cust_type" : "iced_shaken_espresso",
          "flavor" : "nutty",
          "id" : 46,
          "name" : "Iced Brown Sugar Oatmilk Shaken Espresso"
        },
        "Iced Chocolate Almondmilk Shaken Espresso" : {
          "cust_type" : "iced_shaken_espresso",
          "flavor" : "nutty",
          "id" : 47,
          "name" : "Iced Chocolate Almondmilk Shaken Espresso"
        },
        "Iced Shaken Espresso" : {
          "cust_type" : "iced_shaken_espresso",
          "flavor" : "nutty",
          "id" : 48,
          "name" : "Iced Shaken Espresso"
        }
      },
      "Nitro Cold Brews" : {
        "Nitro Cold Brew" : {
          "cust_type" : "nitro",
          "flavor" : "nutty",
          "id" : 39,
          "name" : "Nitro Cold Brew"
        },
        "Starbucks Reserve Nitro Cold Brew" : {
          "cust_type" : "nitro",
          "flavor" : "nutty",
          "id" : 38,
          "name" : "Starbucks Reserve Nitro Cold Brew"
        },
        "Vanilla Sweet Cream Nitro Cold Brew" : {
          "cust_type" : "nitro",
          "flavor" : "nutty",
          "id" : 40,
          "name" : "Vanilla Sweet Cream Nitro Cold Brew"
        }
      }
    },
    "hot_coffee" : {
      "Americanos" : {
        "Caffè Americano" : {
          "cust_type" : "hot_coffee",
          "flavor" : "nutty",
          "id" : 1,
          "name" : "Caffè Americano"
        }
      },
      "Brewed Coffees" : {
        "Caffè Misto" : {
          "cust_type" : "brewed_coffee",
          "flavor" : "nutty",
          "id" : 6,
          "name" : "Caffè Misto"
        },
        "Decaf Pike Place Roast" : {
          "cust_type" : "brewed_coffee",
          "flavor" : "nutty",
          "id" : 9,
          "name" : "Decaf Pike Place Roast"
        },
        "Featured Starbucks Dark Roast Coffee" : {
          "cust_type" : "brewed_coffee",
          "flavor" : "nutty",
          "id" : 7,
          "name" : "Featured Starbucks Dark Roast Coffee"
        },
        "Pike Place Roast" : {
          "cust_type" : "brewed_coffee",
          "flavor" : "nutty",
          "id" : 8,
          "name" : "Pike Place Roast"
        },
        "Veranda Blend" : {
          "cust_type" : "brewed_coffee",
          "flavor" : "nutty",
          "id" : 5,
          "name" : "Veranda Blend"
        }
      },
      "Cappuccinos" : {
        "Cappuccino" : {
          "cust_type" : "cappuccino",
          "flavor" : "nutty",
          "id" : 10,
          "name" : "Cappuccino"
        }
      },
      "Espresso Shots" : {
        "Espresso" : {
          "cust_type" : "espresso",
          "flavor" : "nutty",
          "id" : 11,
          "name" : "Espresso"
        },
        "Espresso Con Panna" : {
          "cust_type" : "espresso",
          "flavor" : "nutty",
          "id" : 12,
          "name" : "Espresso Con Panna"
        }
      },
      "Flat Whites" : {
        "Flat White" : {
          "cust_type" : "flat_white",
          "flavor" : "nutty",
          "id" : 13,
          "name" : "Flat White"
        },
        "Honey Almondmilk Flat White" : {
          "cust_type" : "flat_white",
          "flavor" : "nutty",
          "id" : 14,
          "name" : "Honey Almondmilk Flat White"
        }
      },
      "Lattes" : {
        "Caffè Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 19,
          "name" : "Caffè Latte"
        },
        "Caramel Brulée Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 18,
          "name" : "Caramel Brulée Latte"
        },
        "Chestnut Praline Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 17,
          "name" : "Chestnut Praline Latte"
        },
        "Cinnamon Dolce Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 20,
          "name" : "Cinnamon Dolce Latte"
        },
        "Pistachio Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 15,
          "name" : "Pistachio Latte"
        },
        "Starbucks Blonde Vanilla Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 23,
          "name" : "Starbucks Blonde Vanilla Latte"
        },
        "Starbucks Reserve Hazelnut Bianco Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 22,
          "name" : "Starbucks Reserve Hazelnut Bianco Latte"
        },
        "Starbucks Reserve Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 21,
          "name" : "Starbucks Reserve Latte"
        },
        "Sugar Cookie Almondmilk Latte" : {
          "cust_type" : "latte",
          "flavor" : "nutty",
          "id" : 16,
          "name" : "Sugar Cookie Almondmilk Latte"
        }
      },
      "Macchiatos" : {
        "Caramel Macchiato" : {
          "cust_type" : "macchiatos",
          "flavor" : "nutty",
          "id" : 24,
          "name" : "Caramel Macchiato"
        },
        "Espresso Macchiato" : {
          "cust_type" : "macchiatos",
          "flavor" : "nutty",
          "id" : 25,
          "name" : "Espresso Macchiato"
        }
      },
      "Mochas" : {
        "Caffè Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 29,
          "name" : "Caffè Mocha"
        },
        "Peppermint Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 28,
          "name" : "Peppermint Mocha"
        },
        "Peppermint White Chocolate Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 27,
          "name" : "Peppermint White Chocolate Mocha"
        },
        "Starbucks Reserve Dark Chocolate Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 30,
          "name" : "Starbucks Reserve Dark Chocolate Mocha"
        },
        "Toasted White Chocolate Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 26,
          "name" : "Toasted White Chocolate Mocha"
        },
        "White Chocolate Mocha" : {
          "cust_type" : "mochas",
          "flavor" : "nutty",
          "id" : 31,
          "name" : "White Chocolate Mocha"
        }
      }
    }
  },
  "user-item-db" : {
    "262ZKKD4IDWdNTa6BeSHtEljKJi1" : {
      "34" : 9,
      "39" : 7,
      "41" : 10,
      "49" : 9
    },
    "test_user1" : {
      "42" : 7,
      "43" : 9,
      "50" : 2,
      "57" : 8
    },
    "test_user10" : {
      "64" : 5,
      "66" : 9,
      "67" : 10
    },
    "test_user2" : {
      "40" : 9,
      "61" : 8
    },
    "test_user3" : {
      "36" : 10,
      "42" : 5,
      "57" : 10,
      "58" : 3,
      "61" : 8,
      "65" : 10
    },
    "test_user4" : {
      "63" : 1
    },
    "test_user5" : {
      "41" : 5,
      "64" : 4
    },
    "test_user6" : {
      "34" : 8,
      "36" : 3
    },
    "test_user7" : {
      "54" : 2,
      "66" : 7
    },
    "test_user8" : {
      "59" : 8,
      "69" : 2
    },
    "test_user9" : {
      "52" : 7
    }
  },
  "users" : {
    "262ZKKD4IDWdNTa6BeSHtEljKJi1" : {
      "drinks" : {
        "drinkid_goes-here" : {
          "drink-name" : "placeholder"
        }
      },
      "email" : "testuser@email.com",
      "name" : "test"
    },
    "test_user1" : "placeholder",
    "test_user10" : "placeholder",
    "test_user2" : "placeholder",
    "test_user3" : "placeholder",
    "test_user4" : "placeholder",
    "test_user5" : "placeholder",
    "test_user6" : "placeholder",
    "test_user7" : "placeholder",
    "test_user8" : "placeholder",
    "test_user9" : "placeholder"
  }
}
)
# Out:
# {'cust_db': {'drinks': {'hot_coffee': {'test': {'test': 'test'}}}},
#  'product_db': {'cold_coffee': {'Cold Brews': {'Irish Cream Cold Brew': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
#      'id': 32,
#      'name': 'Irish Cream Cold Brew'},
#     'Salted Caramel Cream Cold Brew': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
#      'id': 33,
#      'name': 'Salted Caramel Cream Cold Brew'},
#     'Starbucks Cold Brew Coffee': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
#      'id': 35,
#      'name': 'Starbucks Cold Brew Coffee'},
#     'Starbucks Cold Brew Coffee with Milk': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
#      'id': 37,
#      'name': 'Starbucks Cold Brew Coffee with Milk'},
#     'Starbucks Reserve Cold Brew': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
#      'id': 34,
#      'name': 'Starbucks Reserve Cold Brew'},
#     'Vanilla Sweet Cream Cold Brew': {'cust_type': 'cold_brew',
#      'flavor': 'nutty',
# ...

# %%
# product_db testing
product_db_ref = db.child("product_db")
inventory = product_db_ref.get().val()

ids = []
flavors = []
for i in range(1, 146):
    try:
        ids.append(i)
        flavors.append(inventory[i]['flavor'])
        # print(i, inventory[i]['flavor'])    
    except:
        print("error at",i)

flavors_ids_map = dict(zip(ids, flavors))
print(flavors_ids_map[19])

# print(flavors_ids_map[1])
# print()
# Out:
# Hot Coffee
# error at 94
# ['smooth']

# %%
# user-drink-db testing
# getting dummy
db_ref = db.child("user-item-db")
user_id = "test_user4"
user_ref = db_ref.child(user_id)
inventory = user_ref.get().val()

print(inventory['3'])
# Out:
# 7

# %%
# test to be displayed in index page
from order import userOrderInit

from app import firebase
from order import getIndexToBeDisplay
db = firebase.database()
user_id = "NzkGCghmk4MO4mCjwn3DQ8n3LxH2"
[order_list, usualOrders] = userOrderInit(user_id, db)
print(usualOrders[0].name)
getIndexToBeDisplay(usualOrders)
# Out:
# Vito Morning Special
# ['Vito Morning Special: 1 tall Chestnut Praline Latte, ',
#  'Vito favorite 1: 1 small Peppermint White Chocolate Mocha, 1 venti Caramel Frappuccino']
